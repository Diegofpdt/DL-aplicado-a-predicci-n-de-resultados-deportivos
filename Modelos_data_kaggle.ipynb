# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import itertools
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
folder1 = "Data"
folder2 = "main"
años = ["18_19", "19_20", "20_21", "21_22", "22_23", "23_24"]
torneos = []

for año in años:
    folder3 = año
    match_file = f"E0.csv"
    path_matches = os.path.join(folder1, folder2,folder3, match_file)
    matches = pd.read_csv(path_matches)
    torneos.append(matches)

# %%
torneos[0].tail()
# Out:
#     Div        Date     HomeTeam      AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 375  E0  12/05/2019    Liverpool        Wolves     2     0   H     1     0
# 376  E0  12/05/2019   Man United       Cardiff     0     2   A     0     1
# 377  E0  12/05/2019  Southampton  Huddersfield     1     1   D     1     0
# 378  E0  12/05/2019    Tottenham       Everton     2     2   D     1     0
# 379  E0  12/05/2019      Watford      West Ham     1     4   A     0     2
#
#     HTR  ... BbAv<2.5  BbAH  BbAHh  BbMxAHH  BbAvAHH  BbMxAHA  BbAvAHA  PSCH  \
# 375   H  ...     2.31    22   -1.5     1.98     1.91     2.01     1.95  1.32
# 376   A  ...     2.95    21   -2.0     2.52     2.32     1.72     1.64  1.30
# 377   H  ...     2.29    22   -1.5     2.27     2.16     1.80     1.73  1.37
# 378   H  ...     2.07    19   -0.5     2.13     2.08     1.85     1.80  1.91
# 379   A  ...     2.44    19   -0.5     2.25     2.19     1.78     1.72  2.11
#
#      PSCD  PSCA
# 375  5.89  9.48
# 376  6.06  9.71
# ...

# %%
torneos[0].columns
# Out:
# Index(['Div', 'Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG',
#        'HTAG', 'HTR', 'Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC',
#        'AC', 'HY', 'AY', 'HR', 'AR', 'B365H', 'B365D', 'B365A', 'BWH', 'BWD',
#        'BWA', 'IWH', 'IWD', 'IWA', 'PSH', 'PSD', 'PSA', 'WHH', 'WHD', 'WHA',
#        'VCH', 'VCD', 'VCA', 'Bb1X2', 'BbMxH', 'BbAvH', 'BbMxD', 'BbAvD',
#        'BbMxA', 'BbAvA', 'BbOU', 'BbMx>2.5', 'BbAv>2.5', 'BbMx<2.5',
#        'BbAv<2.5', 'BbAH', 'BbAHh', 'BbMxAHH', 'BbAvAHH', 'BbMxAHA', 'BbAvAHA',
#        'PSCH', 'PSCD', 'PSCA'],
#       dtype='object')

# %%
index_of_AR = torneos[0].columns.tolist().index("AR")

torneos2 = []
for torneo in torneos:
    torneo2 = torneo.drop(list(torneo.columns[index_of_AR+1:])+["Referee", "Div"], axis=1)
    torneos2.append(torneo2)

torneos2[0].columns
# Out:
# Index(['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG', 'HTAG',
#        'HTR', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY', 'AY',
#        'HR', 'AR'],
#       dtype='object')

# %%
torneos2[0]
# Out:
#            Date      HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0    10/08/2018    Man United       Leicester     2     1   H     1     0   H
# 1    11/08/2018   Bournemouth         Cardiff     2     0   H     1     0   H
# 2    11/08/2018        Fulham  Crystal Palace     0     2   A     0     1   A
# 3    11/08/2018  Huddersfield         Chelsea     0     3   A     0     2   A
# 4    11/08/2018     Newcastle       Tottenham     1     2   A     1     2   A
# ..          ...           ...             ...   ...   ...  ..   ...   ...  ..
# 375  12/05/2019     Liverpool          Wolves     2     0   H     1     0   H
# 376  12/05/2019    Man United         Cardiff     0     2   A     0     1   A
# 377  12/05/2019   Southampton    Huddersfield     1     1   D     1     0   H
# 378  12/05/2019     Tottenham         Everton     2     2   D     1     0   H
# 379  12/05/2019       Watford        West Ham     1     4   A     0     2   A
#
# ...
